# %% [markdown]
# ## Վերլուծում ենք Լավագույն շախմատիստուհիների տվյալները։

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("top_women_chess_players_aug_2020.csv")
df
# Out:
#       Fide id                     Name Federation Gender  Year_of_birth Title  \
# 0      700070            Polgar, Judit        HUN      F         1976.0    GM
# 1     8602980               Hou, Yifan        CHN      F         1994.0    GM
# 2     5008123            Koneru, Humpy        IND      F         1987.0    GM
# 3     4147103  Goryachkina, Aleksandra        RUS      F         1998.0    GM
# 4      700088            Polgar, Susan        HUN      F         1969.0    GM
# ...       ...                      ...        ...    ...            ...   ...
# 8548  3302288        Reinkens, Natalia        BOL      F            NaN   NaN
# 8549   343960        Saffova, Michaela        CZE      F         1994.0   NaN
# 8550  5038294         Shetye, Siddhali        IND      F         1992.0   NaN
# 8551  2072491            Trakru, Priya        USA      F         2001.0   WFM
# 8552  4666399      Vorpahl, Sina Fleur        GER      F         1982.0   NaN
#
#       Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# 0                2675        2646.0        2736.0            wi
# 1                2658        2621.0        2601.0           NaN
# 2                2586        2483.0        2483.0           NaN
# 3                2582        2502.0        2441.0           NaN
# 4                2577           NaN           NaN            wi
# ...               ...           ...           ...           ...
# 8548             1801           NaN           NaN            wi
# 8549             1801        1791.0        1765.0           NaN
# 8550             1801        1884.0        1824.0            wi
# 8551             1801           NaN           NaN            wi
# 8552             1801           NaN           NaN            wi
#
# [8553 rows x 10 columns]

# %% [markdown]
# Հիմա տպենք, լավագույն 10 շախմատիստուհիներին։

# %%
top_10 = df.head(10)
top_10
# Out:
#     Fide id                     Name Federation Gender  Year_of_birth Title  \
# 0    700070            Polgar, Judit        HUN      F         1976.0    GM
# 1   8602980               Hou, Yifan        CHN      F         1994.0    GM
# 2   5008123            Koneru, Humpy        IND      F         1987.0    GM
# 3   4147103  Goryachkina, Aleksandra        RUS      F         1998.0    GM
# 4    700088            Polgar, Susan        HUN      F         1969.0    GM
# 5   8600147                 Xie, Jun        CHN      F         1970.0    GM
# 6   8603006               Ju, Wenjun        CHN      F         1991.0    GM
# 7  14109336          Lagno, Kateryna        RUS      F         1989.0    GM
# 8  14114550         Muzychuk, Mariya        UKR      F         1992.0    GM
# 9  12801259       Cmilyte, Viktorija        LTU      F         1983.0    GM
#
#    Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# 0             2675        2646.0        2736.0            wi
# 1             2658        2621.0        2601.0           NaN
# 2             2586        2483.0        2483.0           NaN
# 3             2582        2502.0        2441.0           NaN
# 4             2577           NaN           NaN            wi
# 5             2574           NaN           NaN            wi
# 6             2560        2610.0        2536.0           NaN
# 7             2546        2521.0        2608.0           NaN
# 8             2544        2506.0        2326.0           NaN
# 9             2538        2394.0        2435.0            wi

# %%
plt.figure(figsize=(14,8))
plt.title("Լավագույն 10 շախամտիստուհիների վարկանիշները")
sns.barplot(x = "Standard_Rating", y = "Name", data=top_10).set_xlim(2500, 2700)
plt.show()

# %% [markdown]
# Հիմա  գտնենք, միջին շախմատիստուհիների միջին տարիքը, որոնք ակտիվ են։

# %%
df_active = df[df.Inactive_flag != 'wi']
birth_year = df_active.Year_of_birth
current_year = 2020
age_value =  current_year - birth_year
print(f"Ակտիվ խաղացողների միջին տարիքը։  {round(np.nanmean(age_value), 1)} է.")
# Out:
# Ակտիվ խաղացողների միջին տարիքը։  29.5 է.

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.distplot(age_value,  bins = 10, kde=False)
ax.set_ylabel('Ընդհանուր խաղացողներ')
ax.set_xlabel('Տարիք')
ax.set_xticks(range(0,101,10))
plt.title("Ակտիվ խաղացողների տարիքային բաշխում")
plt.show()

# %% [markdown]
# Ինչպես գիտեք, ՖԻԴԵՆ ունի իր տիտղոսները, որոնք տալիս է շախմատիստներին որոշակի վարկանիշների դեպքում։
# Հիմա  կարճ ներկայացնեմ այդ տիտղոսները։
#
#     1.WGM ֊ Կին Գրոսմաստեր
#     2.WFM ֊ Կին ՖԻԴԵ֊ի վարպետ
#     3.WIM ֊ Կին միջազգային վարպետ
#     4.WCM - Կին վարպետի թեկնածու
#     5.WH  ֊ Կին պատվավոր գրոսմաստեր

# %%
title_dist = df.Title.value_counts().reset_index()
print(title_dist)
fig, ax = plt.subplots(figsize=(10,6))
plt.title("Խաղացողների տիտղոսների բաշխում")
sns.barplot(x = "index", y = "Title", data = title_dist)
ax.set_xlabel('FIDE տիտղոս')
ax.set_ylabel('ընդհանուր խաղացողներ')
plt.show()
# Out:
#   index  Title
# 0   WFM   1545
# 1   WIM    809
# 2   WGM    316
# 3   WCM    247
# 4    IM    119
# 5    GM     37
# 6    FM     36
# 7    CM      8
# 8    WH      1

# %% [markdown]
# ##  Շախմատիստուհիների միջին վարկանիշները ըստ տիտղոսների։

# %%
avg_std_rating_per_title = round(df.groupby("Title")["Standard_Rating"].mean(), 2).reset_index().sort_values(by='Standard_Rating', ascending=False).reset_index(drop=True)
print(avg_std_rating_per_title)

plt.figure(figsize=(10,6))
plt.title("Խաղացողների միջին ստանդարտ վարկանիշը ըստ տիտղոսների")
sns.barplot(x = "Title", y="Standard_Rating", data=avg_std_rating_per_title, palette="Reds_d").set_ylim(1800, 2525)
plt.show()
# Out:
#   Title  Standard_Rating
# 0    GM          2482.84
# 1    IM          2354.10
# 2   WGM          2245.35
# 3    FM          2188.14
# 4   WIM          2129.17
# 5    WH          2080.00
# 6   WFM          2049.09
# 7    CM          2017.88
# 8   WCM          1929.95

# %%
avg_rapid_rating_per_title = round(df.groupby("Title")["Rapid_rating"].mean(), 2).reset_index().sort_values(by='Rapid_rating', ascending=False).reset_index(drop=True)
print(avg_rapid_rating_per_title)
plt.figure(figsize=(10,6))
plt.title("Խաղացողների միջին ռափիդ վարկանիշը ըստ տիտղոսների")
sns.barplot(x = "Title", y="Rapid_rating", data=avg_rapid_rating_per_title, palette="Blues_d").set_ylim(1800, 2500)
plt.show()
# Out:
#   Title  Rapid_rating
# 0    GM       2444.27
# 1    IM       2297.93
# 2   WGM       2199.22
# 3   WIM       2066.25
# 4    FM       2023.55
# 5   WFM       1951.98
# 6    CM       1833.83
# 7   WCM       1794.81
# 8    WH           NaN

# %%
avg_blitz_rating_per_title = round(df.groupby("Title")["Blitz_rating"].mean(), 2).reset_index().sort_values(by='Blitz_rating', ascending=False).reset_index(drop=True)
print(avg_blitz_rating_per_title)
plt.figure(figsize=(10,6))
plt.title("Խաղացողների միջին բլից վարկանիշը ըստ տիտղոսների")
sns.barplot(x = "Title", y="Blitz_rating", data=avg_blitz_rating_per_title, palette="Greens_d").set_ylim(1800, 2500)
plt.show()
# Out:
#   Title  Blitz_rating
# 0    GM       2414.94
# 1    IM       2258.86
# 2   WGM       2181.45
# 3   WIM       2045.32
# 4    FM       2008.71
# 5   WFM       1935.86
# 6    CM       1810.00
# 7   WCM       1786.87
# 8    WH           NaN

# %% [markdown]
# ## Թոփ 10 ամենաուժեղ շախմատային երկրների վերլուծություն

# %%
countries_dist = df.Federation.value_counts().reset_index().rename(columns={'index':'Country', 'Federation':'Total players'})[:10]
countries_dist.index += 1
print(countries_dist)


labels = countries_dist['Country']
sizes = countries_dist['Total players']
fig1, ax1 = plt.subplots(figsize=(10,10))
explode = (0.05,0,0,0,0,0,0,0,0,0)
ax1.pie(sizes, explode=explode,labels=labels, autopct='%1.1f%%', startangle=70)
plt.title("Ըստ կին շախմատիստուհիների բաշխման")
plt.show()
# Out:
#    Country  Total players
# 1      RUS           1698
# 2      GER            621
# 3      POL            384
# 4      UKR            287
# 5      IND            284
# 6      ESP            251
# 7      FRA            246
# 8      CUB            235
# 9      HUN            215
# 10     SRB            199

# %%
countries_dist = df[df.Title=='GM'].Federation.value_counts().reset_index().rename(columns={'index':'Country', 'Federation':'Total GMs'})[:10]
print(countries_dist)
plt.figure(figsize=(10,6))
plt.title("Գրոսմաստերների քանակը ըստ երկրների")
sns.barplot(x = "Country", y="Total GMs", data=countries_dist)
plt.show()
# Out:
#   Country  Total GMs
# 0     CHN          7
# 1     RUS          6
# 2     GEO          5
# 3     UKR          4
# 4     HUN          3
# 5     IND          2
# 6     FRA          1
# 7     ARM          1
# 8     QAT          1
# 9     LTU          1

# %% [markdown]
# Ինչպես տեսնում ենք, գրոսմաստերների քանակով առաջատար է Չինաստանը
#
#     2.Ռուսաստան ֊ 6
#     3.Վրաստան ֊ 5
#     4.Ուկրաինա ֊ 4
#
# Հայաստանը ունի ընդամենը 1 կին գրոսմաստեր։
